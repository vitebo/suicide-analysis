# %%
from services.mortality_data_service.model import MortalityDataService
import pandas

# %%
pandas.set_option('display.max_rows', None)
pandas.set_option('display.max_columns', None)
pandas.set_option('display.max_colwidth', -1)

# %%
service = MortalityDataService()

# %%
options_default = {
    'SGrupo_CID-10': '245'
}

# %% [markdown]
# ## Ano com o maior indice

# %%
options = {
    'Coluna': 'Ano_do_Óbito',
    'Linha': 'Faixa_Etária',
}
options.update(options_default)
options
# Out:
# {'Coluna': 'Ano_do_Óbito', 'Linha': 'Faixa_Etária', 'SGrupo_CID-10': '245'}

# %%
content = service.search(options)
table = pandas.read_csv(content, sep=';')

# %%
table
# Out:
#       Faixa Etária  1996  1997  1998  1999  2000  2001  2002  2003  2004  \
# 0   5 a 9 anos      -     -     -     -     -     -     1     1     1
# 1   10 a 14 anos    22    15    13    8     16    15    6     10    9
# 2   15 a 19 anos    151   136   142   106   73    138   111   118   90
# 3   20 a 29 anos    466   466   457   406   344   374   393   404   382
# 4   30 a 39 anos    398   450   409   380   326   352   357   324   322
# 5   40 a 49 anos    294   317   311   301   274   309   279   304   290
# 6   50 a 59 anos    193   196   200   159   167   205   206   216   212
# 7   60 a 69 anos    102   114   116   94    113   125   93    104   113
# 8   70 a 79 anos    72    81    61    57    69    72    69    47    80
# 9   80 anos e mais  29    15    30    29    24    39    37    20    28
# 10  Idade ignorada  5     6     8     7     7     8     3     5     3
# 11  Total           1732  1796  1747  1547  1413  1637  1555  1553  1530
#
# ...

# %% [markdown]
# ## Método mais utilizado

# %%
options = {
    'Coluna': 'Faixa_Etária',
    'Linha': 'Categoria_CID-10',
}
options.update(options_default)
options
# Out:
# {'Coluna': 'Faixa_Etária', 'Linha': 'Categoria_CID-10', 'SGrupo_CID-10': '245'}

# %%
content = service.search(options)

# %%
table_2 = pandas.read_csv(content, sep=';')

# %%
table_2
# Out:
#                                       Categoria CID-10 5 a 9 anos  \
# 0   X60   Auto-int int analg antipir anti-reum n-opiac  -
# 1   X61   Auto-int int a-conv sed hip a-park psic NCOP  -
# 2   X62   Auto-intox intenc narcot psicodislept NCOP    1
# 3   X63   Auto-int int outr subst farm sist nerv auton  -
# 4   X64   Auto-int intenc out drog med subst biolog NE  -
# 5   X65   Auto-intox voluntaria p/alcool                -
# 6   X66   Auto-int int solv org hidrocarb halog vapor   -
# 7   X67   Auto-intox intenc p/outr gases e vapores      -
# 8   X68   Auto-intox intenc a pesticidas                -
# 9   X69   Auto-int intenc outr prod quim subst noc NE   -
# 10  X70   Lesao autoprov intenc enforc estrang sufoc    3
# 11  X71   Lesao autoprov intenc p/afogamento submersao  -
# 12  X72   Lesao autoprov intenc disp arma fogo de mao   -
# 13  X73   Les autoprov int disp arm fog maior calibre   -
# 14  X74   Lesao autopr intenc disp outr arma fogo e NE  1
# ...
