# %%
from services.mortality_data_service.model import MortalityDataService
import pandas

# %%
service = MortalityDataService()

# %%
options_default = {
    'Linha': 'Categoria_CID-10',
    'Coluna': 'Sexo',
    'SGrupo_CID-10': '245'
}

# %%
content = service.search(options_default)
# Out:
# Linha=Categoria_CID-10&Coluna=Sexo&Incremento=Óbitos_p/Residênc&Arquivos=obtsp00.dbf&Arquivos=obtsp01.dbf&Arquivos=obtsp02.dbf&Arquivos=obtsp03.dbf&Arquivos=obtsp04.dbf&Arquivos=obtsp05.dbf&Arquivos=obtsp06.dbf&Arquivos=obtsp07.dbf&Arquivos=obtsp08.dbf&Arquivos=obtsp09.dbf&Arquivos=obtsp10.dbf&Arquivos=obtsp11.dbf&Arquivos=obtsp12.dbf&Arquivos=obtsp13.dbf&Arquivos=obtsp14.dbf&Arquivos=obtsp15.dbf&Arquivos=obtsp16.dbf&Arquivos=obtsp96.dbf&Arquivos=obtsp97.dbf&Arquivos=obtsp98.dbf&Arquivos=obtsp99.dbf&SMunicípio=TODAS_AS_CATEGORIAS__&SRegião_de_Saúde_(CIR)=TODAS_AS_CATEGORIAS__&SMacrorregião_de_Saúde=TODAS_AS_CATEGORIAS__&SDivisão_administ_estadual=TODAS_AS_CATEGORIAS__&SMicrorregião_IBGE=TODAS_AS_CATEGORIAS__&SRegião_Metropolitana_-_RIDE=TODAS_AS_CATEGORIAS__&SCapítulo_CID-10=TODAS_AS_CATEGORIAS__&SGrupo_CID-10=245&SCausa_-_CID-BR-10=TODAS_AS_CATEGORIAS__&SCausa_mal_definidas=TODAS_AS_CATEGORIAS__&SFaixa_Etária=TODAS_AS_CATEGORIAS__&SFaixa_Etária_OPS=TODAS_AS_CATEGORIAS__&SFaixa_Etária_det=TODAS_AS_CATEGORIAS__&SFx.Etária_Menor_1A=TODAS_AS_CATEGORIAS__&SSexo=TODAS_AS_CATEGORIAS__&SCor/raça=TODAS_AS_CATEGORIAS__&SEscolaridade=TODAS_AS_CATEGORIAS__&SEstado_civil=TODAS_AS_CATEGORIAS__&SLocal_ocorrência=TODAS_AS_CATEGORIAS__&formato=prn&

# %%
pandas.read_csv(content, sep=';')
# Out:
#                                      Categoria CID-10   Masc   Fem Ign  Total
# 0   X60   Auto-int int analg antipir anti-reum n-o...     15    10   -     25
# 1   X61   Auto-int int a-conv sed hip a-park psic ...    224   320   -    544
# 2    X62   Auto-intox intenc narcot psicodislept NCOP     99    21   -    120
# 3   X63   Auto-int int outr subst farm sist nerv a...     13    12   -     25
# 4   X64   Auto-int intenc out drog med subst biolo...    260   274   -    534
# 5                X65   Auto-intox voluntaria p/alcool     58    22   -     80
# 6   X66   Auto-int int solv org hidrocarb halog vapor     25    11   -     36
# 7      X67   Auto-intox intenc p/outr gases e vapores     90    25   -    115
# 8                X68   Auto-intox intenc a pesticidas    961   464   1   1426
# 9   X69   Auto-int intenc outr prod quim subst noc NE    933   533   -   1466
# 10   X70   Lesao autoprov intenc enforc estrang sufoc  17630  2683   3  20316
# 11  X71   Lesao autoprov intenc p/afogamento subme...    199   139   -    338
# 12  X72   Lesao autoprov intenc disp arma fogo de mao    446    41   -    487
# 13  X73   Les autoprov int disp arm fog maior calibre     44     2   -     46
# 14  X74   Lesao autopr intenc disp outr arma fogo ...   3755   459   -   4214
# 15      X75   Lesao autoprov intenc p/disp explosivos     15     2   -     17
# 16   X76   Lesao autoprov intenc fumaca fogo e chamas    459   641   -   1100
# 17   X77   Lesao autopr int vapor agua gas  obj quent     14     1   -     15
# 18   X78   Lesao autoprov intenc obj cortante  penetr    646   109   -    755
# 19   X79   Lesao autoprov intenc p/objeto contundente   1065   302   -   1367
# 20   X80   Lesao autoprov intenc precip lugar elevado   1437   803   -   2240
# 21  X81   Lesao autoprov intenc precip perm obj movim    123    42   -    165
# 22   X82   Lesao autoprov intenc impacto veic a motor    265    73   -    338
# 23     X83   Lesao autoprov intenc p/outr meios espec     54    19   -     73
# 24             X84   Lesao autoprov intenc p/meios NE   1879   727   -   2606
# 25                                              Total  30709  7735   4  38448
