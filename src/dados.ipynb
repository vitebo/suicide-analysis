# %%
from services.mortality_data_service.model import MortalityDataService
import pandas

# %%
service = MortalityDataService()

# %%
options_default = {
    'Linha': 'Categoria_CID-10',
    'SGrupo_CID-10': '245'
}

# %%
content = service.search(options_default)

# %%
pandas.read_csv(content, sep=';')
# Out:
#                                      Categoria CID-10  Óbitos p/Residênc
# 0   X60   Auto-int int analg antipir anti-reum n-o...                  4
# 1   X61   Auto-int int a-conv sed hip a-park psic ...                 34
# 2    X62   Auto-intox intenc narcot psicodislept NCOP                 11
# 3   X63   Auto-int int outr subst farm sist nerv a...                  2
# 4   X64   Auto-int intenc out drog med subst biolo...                 48
# 5                X65   Auto-intox voluntaria p/alcool                  6
# 6   X66   Auto-int int solv org hidrocarb halog vapor                  2
# 7      X67   Auto-intox intenc p/outr gases e vapores                  7
# 8                X68   Auto-intox intenc a pesticidas                 54
# 9   X69   Auto-int intenc outr prod quim subst noc NE                 32
# 10   X70   Lesao autoprov intenc enforc estrang sufoc               1398
# 11  X71   Lesao autoprov intenc p/afogamento subme...                 16
# 12  X72   Lesao autoprov intenc disp arma fogo de mao                 48
# 13  X74   Lesao autopr intenc disp outr arma fogo ...                141
# 14   X76   Lesao autoprov intenc fumaca fogo e chamas                 42
# 15   X77   Lesao autopr int vapor agua gas  obj quent                  1
# 16   X78   Lesao autoprov intenc obj cortante  penetr                 39
# 17   X79   Lesao autoprov intenc p/objeto contundente                 21
# 18   X80   Lesao autoprov intenc precip lugar elevado                187
# 19  X81   Lesao autoprov intenc precip perm obj movim                 10
# 20   X82   Lesao autoprov intenc impacto veic a motor                 21
# 21     X83   Lesao autoprov intenc p/outr meios espec                  6
# 22             X84   Lesao autoprov intenc p/meios NE                 69
# 23                                              Total               2199
