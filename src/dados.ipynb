# %%
from services.mortality_data_service.model import MortalityDataService
import pandas

# %%
pandas.set_option('display.max_rows', None)
pandas.set_option('display.max_columns', None)
pandas.set_option('display.max_colwidth', -1)

# %%
service = MortalityDataService()

# %%
options_default = {
    'SGrupo_CID-10': '245'
}

# %% [markdown]
# ## Ano com o maior indice

# %%
options = {
    'Linha': 'Ano_do_Óbito',
    'Coluna': 'Capítulo_CID-10'
}
options.update(options_default)
options
# Out:
# {'Coluna': 'Capítulo_CID-10', 'Linha': 'Ano_do_Óbito', 'SGrupo_CID-10': '245'}

# %%
content = service.search(options)

# %%
table = pandas.read_csv(content, sep=';')

# %%
table_f = table.drop(columns=['Cap XX'])
table_f = table_f.drop(21, 0)
table_f.plot(x='Ano do Óbito', y='Total', kind='bar')

# %% [markdown]
# ## Método mais utilizado no ano de maior indice

# %%
options = {
    'Linha': 'Categoria_CID-10',
    'Coluna': 'Ano_do_Óbito',
    'Arquivos': 'obtsp15.dbf'
}
options.update(options_default)
options
# Out:
# {'Arquivos': 'obtsp15.dbf',
#  'Coluna': 'Ano_do_Óbito',
#  'Linha': 'Categoria_CID-10',
#  'SGrupo_CID-10': '245'}

# %%
content = service.search(options)
table_2 = pandas.read_csv(content, sep=';')

# %%
table_2_f = table_2.drop(24, 0)
table_2_f = table_2_f.drop(columns=['Total'])
table_2_f.plot(x='Categoria CID-10', y='2015', kind='barh')

# %% [markdown]
# ## Sexo com maor indice utilizando X70 no ano de 2015

# %%
options = {
    'Linha': 'Sexo',
    'Arquivos': 'obtsp15.dbf',
    'SCategoria_CID-10': '1835',
}
options.update(options_default)
options
# Out:
# {'Arquivos': 'obtsp15.dbf',
#  'Linha': 'Sexo',
#  'SCategoria_CID-10': '1835',
#  'SGrupo_CID-10': '245'}

# %%
content = service.search(options)
table_3 = pandas.read_csv(content, sep=';')

# %%
table_3 = table_3.drop(2, 0)
table_3
# Out:
#    Sexo  Óbitos p/Residênc
# 0  Masc  1817
# 1  Fem   483

# %%
table_3.plot(kind='bar', x='Sexo')
