# %%
from services.mortality_data_service.model import MortalityDataService
import pandas

# %%
service = SuicideDataService()

# %%
content = service.search()

# %%
pandas.read_csv(content, sep=';')
# Out:
#                           Município  Óbitos p/Residênc
# 0                 350010 Adamantina                319
# 1                     350020 Adolfo                 32
# 2                      350030 Aguaí                244
# 3             350040 Águas da Prata                 83
# 4           350050 Águas de Lindóia                154
# 5     350055 Águas de Santa Bárbara                 46
# 6         350060 Águas de São Pedro                 29
# 7                     350070 Agudos                271
# 8                   350075 Alambari                 34
# 9          350080 Alfredo Marcondes                 33
# 10                    350090 Altair                 31
# 11               350100 Altinópolis                129
# 12               350110 Alto Alegre                 32
# 13                  350115 Alumínio                124
# 14          350120 Álvares Florence                 31
# 15           350130 Álvares Machado                185
# 16        350140 Álvaro de Carvalho                 27
# 17               350150 Alvinlândia                 38
# 18                 350160 Americana               1450
# 19       350170 Américo Brasiliense                209
# 20         350180 Américo de Campos                 50
# 21                    350190 Amparo                596
# 22                 350200 Analândia                 31
# 23                 350210 Andradina                508
# 24                  350220 Angatuba                161
# 25                   350230 Anhembi                 51
# 26                   350240 Anhumas                 34
# 27                 350250 Aparecida                296
# 28         350260 Aparecida d'Oeste                 46
# 29                     350270 Apiaí                213
# ..                              ...                ...
# 617                   355495 Tuiuti                 52
# 618                     355500 Tupã                658
# 619            355510 Tupi Paulista                155
# 620                  355520 Turiúba                 20
# 621                355530 Turmalina                 18
# 622                  355535 Ubarana                 33
# 623                  355540 Ubatuba                562
# 624                355550 Ubirajara                 39
# 625                    355560 Uchoa                 85
# 626           355570 União Paulista                 18
# 627                   355580 Urânia                 82
# 628                      355590 Uru                 17
# 629                   355600 Urupês                108
# 630          355610 Valentim Gentil                 69
# 631                 355620 Valinhos                812
# 632               355630 Valparaíso                177
# 633                   355635 Vargem                 75
# 634     355640 Vargem Grande do Sul                278
# 635   355645 Vargem Grande Paulista                285
# 636          355650 Várzea Paulista                560
# 637                355660 Vera Cruz                102
# 638                  355670 Vinhedo                399
# 639                355680 Viradouro                127
# 640     355690 Vista Alegre do Alto                 35
# 641           355695 Vitória Brasil                 16
# 642               355700 Votorantim                764
# 643              355710 Votuporanga                625
# 644                 355715 Zacarias                 20
# 645  350000 Município ignorado - SP                587
# 646                           Total             296359
#
# [647 rows x 2 columns]
