# %%
from services.mortality_data_service.model import MortalityDataService
import pandas

# %%
service = MortalityDataService()

# %%
options_default = {
    'Linha': 'Categoria_CID-10',
    'SGrupo_CID-10': '245'
}

# %%
content = service.search(options_default)

# %%
pandas.read_csv(content, sep=';')
# Out:
#                                      Categoria CID-10  Óbitos p/Residênc  \
# 0   X60   Auto-int int analg antipir anti-reum n-o...                 25
# 1   X61   Auto-int int a-conv sed hip a-park psic ...                544
# 2    X62   Auto-intox intenc narcot psicodislept NCOP                120
# 3   X63   Auto-int int outr subst farm sist nerv a...                 25
# 4   X64   Auto-int intenc out drog med subst biolo...                534
# 5                X65   Auto-intox voluntaria p/alcool                 80
# 6   X66   Auto-int int solv org hidrocarb halog vapor                 36
# 7      X67   Auto-intox intenc p/outr gases e vapores                115
# 8                X68   Auto-intox intenc a pesticidas               1426
# 9   X69   Auto-int intenc outr prod quim subst noc NE               1466
# 10   X70   Lesao autoprov intenc enforc estrang sufoc              20316
# 11  X71   Lesao autoprov intenc p/afogamento subme...                338
# 12  X72   Lesao autoprov intenc disp arma fogo de mao                487
# 13  X73   Les autoprov int disp arm fog maior calibre                 46
# 14  X74   Lesao autopr intenc disp outr arma fogo ...               4214
# 15      X75   Lesao autoprov intenc p/disp explosivos                 17
# 16   X76   Lesao autoprov intenc fumaca fogo e chamas               1100
# 17   X77   Lesao autopr int vapor agua gas  obj quent                 15
# 18   X78   Lesao autoprov intenc obj cortante  penetr                755
# 19   X79   Lesao autoprov intenc p/objeto contundente               1367
# 20   X80   Lesao autoprov intenc precip lugar elevado               2240
# 21  X81   Lesao autoprov intenc precip perm obj movim                165
# 22   X82   Lesao autoprov intenc impacto veic a motor                338
# 23     X83   Lesao autoprov intenc p/outr meios espec                 73
# 24             X84   Lesao autoprov intenc p/meios NE               2606
# 25                                              Total              38448
#
#     Óbitos p/Ocorrênc
# 0                  25
# 1                 542
# 2                 120
# 3                  25
# 4                 531
# 5                  81
# 6                  36
# 7                 113
# 8                1430
# 9                1483
# 10              20320
# 11                331
# 12                484
# 13                 46
# 14               4216
# 15                 17
# 16               1109
# 17                 15
# 18                751
# 19               1372
# 20               2241
# 21                164
# 22                341
# 23                 74
# 24               2604
# 25              38471
